# %%
pip install google-generativeai speechrecognition pyttsx3 websockets asyncio
# Out:
# ...
#
# [notice] A new release of pip is available: 24.0 -> 25.2
# [notice] To update, run: pip3 install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.

# %%
import google.generativeai as genai
import speech_recognition as sr
import pyttsx3
import asyncio
import websockets
import json
from datetime import datetime

# --- Gemini Setup ---
genai.configure(api_key="AIzaSyADZotZUQJpM_-3ovOK-KjC1LLaUlzl_xs")

model = genai.GenerativeModel("gemini-1.5-flash")

# --- Pyttsx3 Setup ---
engine = pyttsx3.init()
engine.setProperty('rate', 175)
engine.setProperty('volume', 1.0)

# --- Speech Recognition Setup ---
recognizer = sr.Recognizer()
mic = sr.Microphone()
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# File /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/speech_recognition/__init__.py:103, in Microphone.get_pyaudio()
#     102 try:
# --> 103     import pyaudio
#     104 except ImportError:
#
# ModuleNotFoundError: No module named 'pyaudio'
#
# During handling of the above exception, another exception occurred:
#
# AttributeError                            Traceback (most recent call last)
# Cell In[10], line 21
#      19 # --- Speech Recognition Setup ---
#      20 recognizer = sr.Recognizer()
# ---> 21 mic = sr.Microphone()
#
# File /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/speech_recognition/__init__.py:75, in Microphone.__init__(self, device_index, sample_rate, chunk_size)
# ...

# %%
pip install pyaudio
# Out:
# ...
#   Using cached PyAudio-0.2.14.tar.gz (47 kB)
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# ...
#   error: subprocess-exited-with-error
#
#   × Building wheel for pyaudio (pyproject.toml) did not run successfully.
#   │ exit code: 1
#   ╰─> [27 lines of output]
#       /private/var/folders/y_/tdchl6317_12pkk7d6d5l5m40000gn/T/pip-build-env-5pjuj7af/overlay/lib/python3.12/site-packages/setuptools/dist.py:759: SetuptoolsDeprecationWarning: License classifiers are deprecated.
#       !!
#
#               ********************************************************************************
#               Please consider removing the following classifiers in favor of a SPDX license expression:
#
#               License :: OSI Approved :: MIT License
#
#               See https://packaging.python.org/en/latest/guides/writing-pyproject-toml/#license for details.
# ...

# %%
import sounddevice as sd
import numpy as np
import io, wave, speech_recognition as sr

recognizer = sr.Recognizer()

def listen():
    print("🎤 Listening (no PyAudio)...")
    samplerate = 16000
    duration = 5  # seconds
    audio_data = sd.rec(int(duration * samplerate),
                        samplerate=samplerate,
                        channels=1,
                        dtype='int16')
    sd.wait()
    wav_bytes = io.BytesIO()
    with wave.open(wav_bytes, 'wb') as wf:
        wf.setnchannels(1)
        wf.setsampwidth(2)
        wf.setframerate(samplerate)
        wf.writeframes(audio_data.tobytes())
    wav_bytes.seek(0)
    with sr.AudioFile(wav_bytes) as source:
        audio = recognizer.record(source)
    try:
        text = recognizer.recognize_google(audio)
        print("🗣️ You said:", text)
        return text
    except Exception as e:
        print("❌ Error:", e)
        return None
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[9], line 1
# ----> 1 import sounddevice as sd
#       2 import numpy as np
#       3 import io, wave, speech_recognition as sr
#
# ModuleNotFoundError: No module named 'sounddevice'
